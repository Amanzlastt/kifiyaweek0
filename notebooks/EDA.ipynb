# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_benin = pd.read_csv("/content/drive/MyDrive/data/benin-malanville.csv")
df_sierra = pd.read_csv("/content/drive/MyDrive/data/sierraleone-bumbuna.csv")
df_togo = pd.read_csv("/content/drive/MyDrive/data/togo-dapaong_qc.csv")

# %%
df_benin.describe()
# Out:
#                  GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      240.559452     167.187516     115.358961     236.589496
# std       331.131327     261.710501     158.691074     326.894859
# min       -12.900000      -7.800000     -12.600000       0.000000
# 25%        -2.000000      -0.500000      -2.100000       0.000000
# 50%         1.800000      -0.100000       1.600000       4.500000
# 75%       483.400000     314.200000     216.300000     463.700000
# max      1413.000000     952.300000     759.200000    1342.300000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      228.883576      28.179683      54.487969       2.121113
# std       316.536515       5.924297      28.073069       1.603466
# min         0.000000      11.000000       2.100000       0.000000
# ...

# %%
df_togo.describe()
# Out:
#                  GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      230.555040     151.258469     116.444352     226.144375
# std       322.532347     250.956962     156.520714     317.346938
# min       -12.700000       0.000000       0.000000       0.000000
# 25%        -2.200000       0.000000       0.000000       0.000000
# 50%         2.100000       0.000000       2.500000       4.400000
# 75%       442.400000     246.400000     215.700000     422.525000
# max      1424.000000    1004.500000     805.700000    1380.000000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      219.568588      27.751788      55.013160       2.368093
# std       307.932510       4.758023      28.778732       1.462668
# min         0.000000      14.900000       3.300000       0.000000
# ...

# %%
df_sierra.describe()
# Out:
#                  GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      201.957515     116.376337     113.720571     206.643095
# std       298.495150     218.652659     158.946032     300.896893
# min       -19.500000      -7.800000     -17.900000       0.000000
# 25%        -2.800000      -0.300000      -3.800000       0.000000
# 50%         0.300000      -0.100000      -0.100000       3.600000
# 75%       362.400000     107.000000     224.700000     359.500000
# max      1499.000000     946.000000     892.000000    1507.000000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      198.114691      26.319394      79.448857       1.146113
# std       288.889073       4.398605      20.520775       1.239248
# min         0.000000      12.300000       9.900000       0.000000
# ...

# %%
df_benin.isna().sum()
# Out:
# Timestamp             0
# GHI                   0
# DNI                   0
# DHI                   0
# ModA                  0
# ModB                  0
# Tamb                  0
# RH                    0
# WS                    0
# WSgust                0
# WSstdev               0
# WD                    0
# WDstdev               0
# BP                    0
# Cleaning              0
# Precipitation         0
# TModA                 0
# TModB                 0
# Comments         525600
# dtype: int64

# %%
df_togo.isna().sum()
# Out:
# Timestamp             0
# GHI                   0
# DNI                   0
# DHI                   0
# ModA                  0
# ModB                  0
# Tamb                  0
# RH                    0
# WS                    0
# WSgust                0
# WSstdev               0
# WD                    0
# WDstdev               0
# BP                    0
# Cleaning              0
# Precipitation         0
# TModA                 0
# TModB                 0
# Comments         525600
# dtype: int64

# %%
df_sierra.isna().sum()
# Out:
# Timestamp             0
# GHI                   0
# DNI                   0
# DHI                   0
# ModA                  0
# ModB                  0
# Tamb                  0
# RH                    0
# WS                    0
# WSgust                0
# WSstdev               0
# WD                    0
# WDstdev               0
# BP                    0
# Cleaning              0
# Precipitation         0
# TModA                 0
# TModB                 0
# Comments         525600
# dtype: int64

# %% [markdown]
# Checking the outliers

# %%
plt.figure(figsize=(15, 10))
for i, column in enumerate(["ModA", "ModB", "WS", "WSgust"]):
  plt.subplot(3,3,i+1)
  sns.boxplot(y=df_benin[column])
  plt.title(f"Boxplot of {column}")

# %% [markdown]
# checking incorrect entires

# %%
print("negative values\n", df_benin['GHI'][df_benin['GHI'] < 0], df_benin['DNI'][df_benin['DNI'] < 0], df_benin['DHI'][df_benin['DHI'] < 0])
# Out:
# negative values
#  0        -1.2
# 1        -1.1
# 2        -1.1
# 3        -1.1
# 4        -1.0
#          ...
# 525595   -5.5
# 525596   -5.5
# 525597   -5.5
# 525598   -5.5
# 525599   -5.5
# Name: GHI, Length: 258847, dtype: float64 0        -0.2
# 1        -0.2
# 2        -0.2
# 3        -0.1
# 4        -0.1
#          ...
# 525595   -0.1
# 525596   -0.1
# 525597   -0.1
# 525598   -0.1
# 525599   -0.1
# Name: DNI, Length: 275987, dtype: float64 0        -1.1
# 1        -1.1
# 2        -1.1
# 3        -1.0
# 4        -1.0
#          ...
# 525595   -5.9
# 525596   -5.8
# 525597   -5.8
# 525598   -5.8
# 525599   -5.7
# Name: DHI, Length: 259182, dtype: float64

# %%
df_benin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525600 entries, 0 to 525599
# Data columns (total 19 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Timestamp      525600 non-null  object
#  1   GHI            525600 non-null  float64
#  2   DNI            525600 non-null  float64
#  3   DHI            525600 non-null  float64
#  4   ModA           525600 non-null  float64
#  5   ModB           525600 non-null  float64
#  6   Tamb           525600 non-null  float64
#  7   RH             525600 non-null  float64
#  8   WS             525600 non-null  float64
#  9   WSgust         525600 non-null  float64
#  10  WSstdev        525600 non-null  float64
#  11  WD             525600 non-null  float64
#  12  WDstdev        525600 non-null  float64
#  13  BP             525600 non-null  int64
#  14  Cleaning       525600 non-null  int64
#  15  Precipitation  525600 non-null  float64
# ...

# %%
# Converting Timestamp to a date time data type
df_benin['datetime']=pd.to_datetime(df_benin['Timestamp'])
df_togo['datetime']=pd.to_datetime(df_benin['Timestamp'])
df_sierra['datetime']=pd.to_datetime(df_benin['Timestamp'])

# %% [markdown]
# Group the data into monthly average

# %%
df_benin['month']= df_benin['datetime'].dt.month
monthly_avg_benin= df_benin[["GHI","DNI","DHI",'TModA','TModB']].groupby(df_benin['month']).mean()

df_togo['month']= df_togo['datetime'].dt.month
monthly_avg_togo= df_togo[["GHI","DNI","DHI",'TModA','TModB']].groupby(df_togo['month']).mean()

df_sierra['month']= df_sierra['datetime'].dt.month
monthly_avg_sierra= df_sierra[["GHI","DNI","DHI",'TModA','TModB']].groupby(df_sierra['month']).mean()

# %% [markdown]
# Plotting the monthly average to visualize the data

# %%
fig, ax= plt.subplots(3,1, figsize=(10, 15))

# Plotting for Benin
monthly_avg_benin.plot(kind= 'bar', ax=ax[0])
ax[0].set_title('Monthly Average for Benin')
ax[0].set_xlabel('Month')
ax[0].set_ylabel('Average Values')

# plotting for Togo
monthly_avg_togo.plot(kind= 'bar', ax=ax[1])
ax[1].set_title('Monthly Average for Benin')
ax[1].set_xlabel('Month')
ax[1].set_ylabel('Average Values')

# potting for Sierra Leone
monthly_avg_benin.plot(kind= 'bar', ax=ax[2])
ax[2].set_title('Monthly Average for Benin')
ax[2].set_xlabel('Month')
ax[2].set_ylabel('Average Values')

plt.tight_layout() # Adjust layout to prevent overlapping
plt.show()

# %% [markdown]
# Comparing  the impact of celeaning

# %%
cleaned_benin = df_benin[df_benin['Cleaning'] == 1]
not_cleaned_benin = df_benin[df_benin["Cleaning"] == 0]

cleaned_togo = df_benin[df_togo['Cleaning'] == 1]
not_cleaned_togo = df_benin[df_togo["Cleaning"] == 0]

cleaned_sierra = df_benin[df_sierra['Cleaning'] == 1]
not_cleaned_sierra = df_benin[df_sierra["Cleaning"] == 0]

fig,ax =plt.subplots(3,1, figsize=(10, 15))
ax[0].plot(cleaned_benin['datetime'], cleaned_benin['ModA'], label='ModA Cleaned')
ax[0].plot(cleaned_benin['datetime'], cleaned_benin['ModB'], label='ModB Cleaned')
ax[0].set_title('Benin Sensor Redings After Cleaning')

ax[1].plot(cleaned_sierra['datetime'], cleaned_sierra['ModA'], label='ModA Cleaned')
ax[1].plot(cleaned_sierra['datetime'], cleaned_sierra['ModB'], label='ModB Cleaned')
ax[1].set_title('Sierra Sensor Redings After Cleaning')

ax[2].plot(cleaned_togo['datetime'], cleaned_togo['ModA'], label='ModA Cleaned')
ax[2].plot(cleaned_togo['datetime'], cleaned_togo['ModB'], label='ModB Cleaned')
ax[2].set_title('Togo Sensor Redings After Cleaning')
plt.legend()

# %% [markdown]
# Correlation Analysis

# %%
corre_matrix = df_benin[['GHI', 'DNI', 'DHI', 'TModA', 'TModB']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corre_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("correlation matrix of solaR Radiation ans Temperature Measures")
plt.show()

# %%
sns.pairplot(df_togo[['GHI', 'DNI', 'DHI', 'TModA', 'TModB']])
plt.title("Pair plot of soalar radiation Components and Temperature measures")
plt.show()

# %%
wind_columns = ["WS", "WSgust", "WD"]
scatter_data = pd.concat([df_benin[['GHI',"DNI","DHI"]], df_benin[wind_columns]], axis=1)
pd.plotting.scatter_matrix(scatter_data, figsize=(12,12), alpha=0.7, diagonal='kde')
plt.title('Scatter Matrix of Wind Conditions and Solar Irradiance')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-1d99a56843bf> in <cell line: 4>()
#       2 scatter_data = pd.concat([df_benin[['GHI',"DNI","DHI"]], df_benin[wind_columns]], axis=1)
#       3 pd.plotting.scatter_matrix(scatter_data, figsize=(12,12), alpha=0.7, diagonal='kde')
# ----> 4 plt.subtitle('Scatter Matrix of Wind Conditions and Solar Irradiance')
#       5 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'subtitle'
